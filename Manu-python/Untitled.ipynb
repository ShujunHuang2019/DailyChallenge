# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = range(100)
y = [val ** 2 for val in x]
plt.plot(x, y)

# %%
# x = np.linspace(0, 2 * np.pi, 100)
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.linspace(-3, 2, 100)
y = x ** 2 + 2 * x + 1
plt.plot(x, y)

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
z = np.cos(x)
plt.plot(x, y)
plt.plot(x, z)

# %%
sct = np.random.rand(20, 2)
plt.scatter(sct[:, 0], sct[:, 1])

# %%
ghj = [5, 10 ,15, 20, 25]
it =[ 1, 2, 3, 4, 5]
plt.barh(it, ghj)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-af3e003ddf5c> in <module>
#       1 ghj = [5, 10 ,15, 20, 25]
#       2 it =[ 1, 2, 3, 4, 5]
# ----> 3 plt.barh(it, ghj, hight = 0.7)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2446 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
#    2447     return gca().barh(
# -> 2448         y, width, height=height, left=left, align=align, **kwargs)
#    2449
#    2450
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2595         kwargs.setdefault('orientation', 'horizontal')
#    2596         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2597                            align=align, **kwargs)
#    2598         return patches
#    2599
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2430                 label='_nolegend_',
#    2431                 )
# -> 2432             r.update(kwargs)
#    2433             r.get_path()._interpolation_steps = 100
#    2434             if orientation == 'vertical':
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     951                 if not callable(func):
#     952                     raise AttributeError('{!r} object has no property {!r}'
# --> 953                                          .format(type(self).__name__, k))
#     954                 return func(v)
#     955
#
# AttributeError: 'Rectangle' object has no property 'hight'

# %%
(2 ** 31) < 1534236469
# Out:
# False

# %%
x =123

res = str(x)[::-1]

res
# Out:
# '321'

# %%
        if x > 0:
            res = str(x)[::-1]
            if res[0] == 0:
                return(int(res[1:]))
            else:
                return(int(res))
# Out:
#   File "<ipython-input-33-e290b96a9b60>", line 4
#     return(int(res[0:]))
#     ^
# SyntaxError: 'return' outside function

# %%
int(res[1:])
# Out:
# 21

# %%
[1, 22, 3][0:]
# Out:
# [1, 22, 3]

# %%
divmod(x, 10)
# Out:
# (12, 3)
